# %%
#function for extraction of red
def red_extraction(yellow,magenta):
    red = cv2.bitwise_xor(cyan_channel,cv2.bitwise_or(yellow,magenta))
    return red

# %%
#funcion for extraction of green
def green_extraction(cyan,yellow):
    grn = cv2.bitwise_xor(magenta_channel,cv2.bitwise_or(cyan,yellow))
    return green

# %%
#function for extraction of blue
def blue_extraction(cyan,magenta):
    blue = cv2.bitwise_xor(yellow_channel,cv2.bitwise_or(cyan,magenta))
    return blue

# %%
#function for extraction of cyan along with white 
def cyan_extraction(yellow,magenta):
    cyan=cv2.bitwise_and(magenta_channel,yellow_channel)
    return cyan

# %%
#function for extraction of magenta along with white 
def magenta_extraction(cyan,yellow):
    magenta=cv2.bitwise_and(cyan_channel,yellow_channel)
    return magenta

# %%
#function for extractio of yellow along with white 
def yellow_extraction(cyan,magenta):
    yellow=cv2.bitwise_and(cyan_channel,magenta_channel)
    return yellow

# %%
#function for extraction of only cyan
def cyan1_extraction(cyan,white):
    cyan1 = (cv2.bitwise_xor(cyan,white))
    return cyan1

# %%
#function for extraction of only magenta
def magenta1_extraction(magenta,white):
    magenta1 = (cv2.bitwise_xor(cyan,white))
    return magenta1

# %%
#function for exraction of only yellow
def yellow1_extraction(yellow,white):
    yellow1 = (cv2.bitwise_xor(yellow,white))
    return yellow1

# %%
#function for extraction of only white
def white_extraction(magenta,yellow):
    white = cv2.bitwise_and(magenta,yellow)
    return white

# %%
#Morphological dilation_example-1
kernel = np.ones((20,50), np.uint8)   
yellow1_erosion = cv2.erode(yellow1, kernel, iterations=1) 
yellow1_dilation = cv2.dilate(yellow1, kernel, iterations=1) 
cv2.imshow('Input', yellow1) 
cv2.imshow('Erosion', yellow1_erosion) 
cv2.imshow('Dilation', yellow1_dilation) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
plt.imshow(yellow1_dilation,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Morphological erosion_example-1
kernel = np.ones((20,20), np.uint8)   
yellow1_erosion = cv2.erode(yellow1, kernel, iterations=1) 
yellow1_dilation = cv2.dilate(yellow1, kernel, iterations=1) 
cv2.imshow('Input', yellow1) 
cv2.imshow('Erosion', yellow1_erosion) 
cv2.imshow('Dilation', yellow1_dilation) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
plt.imshow(yellow1_erosion,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Morphological dilation_example-2
kernel = np.ones((30,30), np.uint8)   
blue_erosion = cv2.erode(blue, kernel, iterations=1) 
blue_dilation = cv2.dilate(blue, kernel, iterations=1) 
cv2.imshow('Input', blue) 
cv2.imshow('Erosion', blue_erosion) 
cv2.imshow('Dilation', blue_dilation) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
plt.imshow(blue_dilation,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Morphological erosion_example-2
kernel = np.ones((30,30), np.uint8)   
blue_erosion = cv2.erode(blue, kernel, iterations=1) 
blue_dilation = cv2.dilate(blue, kernel, iterations=1) 
cv2.imshow('Input', blue) 
cv2.imshow('Erosion', blue_erosion) 
cv2.imshow('Dilation', blue_dilation) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
plt.imshow(blue_erosion,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Morphological dilation_example-3
kernel = np.ones((30,30), np.uint8)   
magenta_erosion = cv2.erode(magenta, kernel, iterations=1) 
magenta_dilation = cv2.dilate(magenta, kernel, iterations=1) 
cv2.imshow('Input', magenta) 
cv2.imshow('Erosion', magenta_erosion) 
cv2.imshow('Dilation', magenta_dilation) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
plt.imshow(magenta_dilation,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Morphological erosion_example-3
kernel = np.ones((30,30), np.uint8)   
magenta_erosion = cv2.erode(magenta, kernel, iterations=1) 
magenta_dilation = cv2.dilate(magenta, kernel, iterations=1) 
cv2.imshow('Input', magenta) 
cv2.imshow('Erosion', magenta_erosion) 
cv2.imshow('Dilation', magenta_dilation) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
plt.imshow(magenta_erosion,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Morphplogical opening
opening = cv2.morphologyEx(yellow1, cv2.MORPH_OPEN, kernel)
cv2.imshow('Input',ylw1)
cv2.imshow('Opening', opening) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
plt.imshow(opening,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Morphological closing
closing = cv2.morphologyEx(yellow1, cv2.MORPH_CLOSE, kernel)
cv2.imshow('Input',yellow1)
cv2.imshow('Closing', closing) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
plt.imshow(closing,cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">
